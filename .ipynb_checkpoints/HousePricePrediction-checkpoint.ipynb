# %% [markdown]
# HOUSE PRICE PREDICTION

# %%
# !pip install pandas
# !pip install openpyxl
# !pip install matplotlib seaborn
# !pip install scikit-learn
# !pip install lightgbm
# Out:
# Requirement already satisfied: pandas in /home/thaivo/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: openpyxl in /home/thaivo/anaconda3/lib/python3.9/site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /home/thaivo/anaconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: matplotlib in /home/thaivo/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: seaborn in /home/thaivo/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: scipy>=1.0 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: pandas>=0.23 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: six in /home/thaivo/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: scikit-learn in /home/thaivo/anaconda3/lib/python3.9/site-packages (0.24.2)
# Requirement already satisfied: joblib>=0.11 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/thaivo/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.1)
# Collecting lightgbm
#   Using cached lightgbm-4.0.0-py3-none-manylinux_2_28_x86_64.whl (3.0 MB)
# Requirement already satisfied: scipy in /home/thaivo/anaconda3/lib/python3.9/site-packages (from lightgbm) (1.7.1)
# Requirement already satisfied: numpy in /home/thaivo/anaconda3/lib/python3.9/site-packages (from lightgbm) (1.20.3)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.0.0

# %% [markdown]
# # 1. Retrieving the data

# %%
# First, let's import a library called Pandas for data analysis
import pandas as pd 

# Delarce the data path
dataPath =  "./data/HousePricePrediction.xlsx"

# Use pandas to load the data from data path

df = pd.read_excel(dataPath)

# Let's see how a data frame look like, it's just another way to seee the data
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0   0          60       RL     8450    Inside     1Fam            5
# 1   1          20       RL     9600       FR2     1Fam            8
# 2   2          60       RL    11250    Inside     1Fam            5
# 3   3          70       RL     9550    Corner     1Fam            5
# 4   4          60       RL    14260       FR2     1Fam            5
# 5   5          50       RL    14115    Inside     1Fam            5
# 6   6          20       RL    10084    Inside     1Fam            5
# 7   7          60       RL    10382    Corner     1Fam            6
# 8   8          50       RM     6120    Inside     1Fam            5
# 9   9         190       RL     7420    Corner   2fmCon            6
#
#    YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0       2003          2003     VinylSd         0.0        856.0   208500.0
# 1       1976          1976     MetalSd         0.0       1262.0   181500.0
# 2       2001          2002     VinylSd         0.0        920.0   223500.0
# 3       1915          1970     Wd Sdng         0.0        756.0   140000.0
# 4       2000          2000     VinylSd         0.0       1145.0   250000.0
# 5       1993          1995     VinylSd         0.0        796.0   143000.0
# 6       2004          2005     VinylSd         0.0       1686.0   307000.0
# 7       1973          1973     HdBoard        32.0       1107.0   200000.0
# 8       1931          1950     BrkFace         0.0        952.0   129900.0
# 9       1939          1950     MetalSd         0.0        991.0   118000.0

# %% [raw]
# This data contain 2919 records and 13 columns.
# . Id: House ID
# . MSSubClass:  Identifies the type of dwelling (such as a house, apartment, mobile home, houseboat, ...) involved in the sales
# . MSZoning: Identifies the general zoning classification of the sale.
# . LotArea: Lot size in square feet.
# . LotConfig: Configuraion of the lot
# . BldgType: Type of dwelling
# . YearBuilt: Original construction year
# . YearRemodAdd: Remodel date ( same as construction date if no remodeling or additions )
# . Exterior1st: Exterior covering on the house
# . BsmtFinSF2: Type 2 finished square feet.
# . TotalBsmtSF: Total square feet of basement area
# . SalePrice: To be predicted

# %% [markdown]
# # 2. EDA

# %%
df.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallCond    YearBuilt  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean   1459.000000    57.137718   10168.114080     5.564577  1971.312778
# std     842.787043    42.517628    7886.996359     1.113131    30.291442
# min       0.000000    20.000000    1300.000000     1.000000  1872.000000
# 25%     729.500000    20.000000    7478.000000     5.000000  1953.500000
# 50%    1459.000000    50.000000    9453.000000     5.000000  1973.000000
# 75%    2188.500000    70.000000   11570.000000     6.000000  2001.000000
# max    2918.000000   190.000000  215245.000000     9.000000  2010.000000
#
#        YearRemodAdd   BsmtFinSF2  TotalBsmtSF      SalePrice
# count   2919.000000  2918.000000  2918.000000    1460.000000
# mean    1984.264474    49.582248  1051.777587  180921.195890
# std       20.894344   169.205611   440.766258   79442.502883
# min     1950.000000     0.000000     0.000000   34900.000000
# 25%     1965.000000     0.000000   793.000000  129975.000000
# 50%     1993.000000     0.000000   989.500000  163000.000000
# 75%     2004.000000     0.000000  1302.000000  214000.000000
# max     2010.000000  1526.000000  6110.000000  755000.000000

# %%
df.dtypes
# Out:
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotArea           int64
# LotConfig        object
# BldgType         object
# OverallCond       int64
# YearBuilt         int64
# YearRemodAdd      int64
# Exterior1st      object
# BsmtFinSF2      float64
# TotalBsmtSF     float64
# SalePrice       float64
# dtype: object

# %%
#filter non-numberic columns
df.select_dtypes(exclude=["int64","float64"]) # Or you could use df.select_dtypes(include=["object"]) instead
# Out:
#      MSZoning LotConfig BldgType Exterior1st
# 0          RL    Inside     1Fam     VinylSd
# 1          RL       FR2     1Fam     MetalSd
# 2          RL    Inside     1Fam     VinylSd
# 3          RL    Corner     1Fam     Wd Sdng
# 4          RL       FR2     1Fam     VinylSd
# ...       ...       ...      ...         ...
# 2914       RM    Inside    Twnhs     CemntBd
# 2915       RM    Inside   TwnhsE     CemntBd
# 2916       RL    Inside     1Fam     VinylSd
# 2917       RL    Inside     1Fam     HdBoard
# 2918       RL    Inside     1Fam     HdBoard
#
# [2919 rows x 4 columns]

# %%
non_numeric_df = df.select_dtypes(exclude=["int64","float64"])

# Let's see value frequecies at record level
print("Value frequecies at record level")
print(non_numeric_df.value_counts())
print("*"*60)
print("Value frequecies at columns level")
for col in non_numeric_df.columns:
    print(f"Column {col}")
    print(non_numeric_df.groupby(col).size().sort_values(ascending=False))
    print("*"*30)
# Out:
# Value frequecies at record level
# MSZoning  LotConfig  BldgType  Exterior1st
# RL        Inside     1Fam      VinylSd        557
#                                HdBoard        246
#                                Wd Sdng        205
#                                MetalSd        170
#           Corner     1Fam      VinylSd        132
#                                              ...
#           CulDSac    1Fam      WdShing          1
#           Corner     TwnhsE    MetalSd          1
#                                HdBoard          1
#                                CemntBd          1
#           FR2        Duplex    HdBoard          1
# Length: 191, dtype: int64
# ************************************************************
# Value frequecies at columns level
# Column MSZoning
# MSZoning
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# dtype: int64
# ******************************
# Column LotConfig
# LotConfig
# Inside     2133
# Corner      511
# CulDSac     176
# FR2          85
# FR3          14
# dtype: int64
# ******************************
# Column BldgType
# BldgType
# 1Fam      2425
# TwnhsE     227
# Duplex     109
# Twnhs       96
# 2fmCon      62
# dtype: int64
# ******************************
# Column Exterior1st
# Exterior1st
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# CBlock        2
# Stone         2
# ImStucc       1
# dtype: int64
# ******************************

# %%
# First import the following two libs which are often for visualization
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

num_fig_rows, num_fig_cols = 2,2

fig,ax = plt.subplots(num_fig_rows,num_fig_cols,figsize=(10,10))

for row in range(num_fig_rows):
    for col in range(num_fig_cols):
        non_numeric_col = non_numeric_df.columns[row*num_fig_cols + col]
        val_freg = non_numeric_df.groupby(non_numeric_col).size().to_dict()
        ax[row,col].bar(list(val_freg.keys()), list(val_freg.values()))
        ax[row,col].tick_params(labelrotation=45)
        ax[row,col].set_title(non_numeric_col)
fig.tight_layout()
plt.show()

# %% [markdown]
# # 3. Modeling

# %%
#Let's check information if we have columns containing null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            2919 non-null   int64
#  1   MSSubClass    2919 non-null   int64
#  2   MSZoning      2915 non-null   object
#  3   LotArea       2919 non-null   int64
#  4   LotConfig     2919 non-null   object
#  5   BldgType      2919 non-null   object
#  6   OverallCond   2919 non-null   int64
#  7   YearBuilt     2919 non-null   int64
#  8   YearRemodAdd  2919 non-null   int64
#  9   Exterior1st   2918 non-null   object
#  10  BsmtFinSF2    2918 non-null   float64
#  11  TotalBsmtSF   2918 non-null   float64
#  12  SalePrice     1460 non-null   float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 296.6+ KB

# %%
df[df["SalePrice"].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 1460  1460          20       RH    11622    Inside     1Fam            6
# 1461  1461          20       RL    14267    Corner     1Fam            6
# 1462  1462          60       RL    13830    Inside     1Fam            5
# 1463  1463          60       RL     9978    Inside     1Fam            6
# 1464  1464         120       RL     5005    Inside   TwnhsE            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 1460       1961          1961     VinylSd       144.0        882.0        NaN
# 1461       1958          1958     Wd Sdng         0.0       1329.0        NaN
# 1462       1997          1998     VinylSd         0.0        928.0        NaN
# 1463       1998          1998     VinylSd         0.0        926.0        NaN
# 1464       1992          1992     HdBoard         0.0       1280.0        NaN
# ...         ...           ...         ...         ...          ...        ...
# 2914       1970          1970     CemntBd         0.0        546.0        NaN
# 2915       1970          1970     CemntBd         0.0        546.0        NaN
# 2916       1960          1996     VinylSd         0.0       1224.0        NaN
# 2917       1992          1992     HdBoard         0.0        912.0        NaN
# 2918       1993          1994     HdBoard         0.0        996.0        NaN
#
# [1459 rows x 13 columns]

# %%
clear_df = df[~df["SalePrice"].isnull()]
